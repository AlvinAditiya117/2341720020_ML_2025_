# %% [markdown]
# #**Langkah 0 - Instal Library**

# %%
# !pip install Pillow
# Out:
# Requirement already satisfied: Pillow in /usr/local/lib/python3.12/dist-packages (11.3.0)

# %% [markdown]
# #**Langkah 1 - Load Image**

# %%
from PIL import Image

img = Image.open('profil.jpg')
img.show() # tampilkan gambar
display(img) # metode alternatif tampilkan gambar
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=864x1296>

# %% [markdown]
# #**Langkah 2 - Ekstrak Fitur**

# %%
# Ekstrak setiap channel red, green, blue
r, g, b = img.split()

# Cek panjang ukuran channel red
print(len(r.histogram()))

# Cetak fitur histogram pada channel red
print(r.histogram())
# Out:
# 256
# [0, 0, 0, 0, 0, 0, 0, 1, 15, 22, 16, 24, 28, 52, 99, 157, 276, 337, 409, 507, 584, 900, 1346, 1718, 2240, 2776, 3177, 3641, 4138, 5558, 9701, 15543, 17883, 18245, 13972, 15139, 23096, 27673, 25568, 30786, 24804, 23309, 24843, 19432, 17292, 17380, 10871, 6422, 5326, 4607, 4240, 3596, 2996, 2474, 2274, 2083, 1945, 1819, 1866, 1587, 1801, 1650, 1817, 1733, 1579, 1588, 1513, 1499, 1368, 1300, 1205, 1092, 1039, 1070, 953, 991, 922, 890, 893, 822, 834, 810, 880, 876, 821, 819, 826, 674, 749, 687, 607, 624, 538, 514, 453, 435, 435, 397, 364, 350, 327, 332, 284, 280, 264, 270, 231, 239, 233, 248, 247, 216, 240, 211, 224, 230, 233, 224, 214, 212, 230, 237, 240, 226, 221, 258, 249, 258, 251, 245, 283, 338, 350, 327, 346, 358, 397, 381, 438, 441, 494, 560, 618, 638, 674, 686, 720, 833, 876, 902, 1053, 1015, 1052, 1062, 1183, 1198, 1368, 1641, 2023, 1842, 3734, 9511, 3758, 275644, 129725, 17266, 20206, 8843, 2254, 1931, 1888, 1858, 1867, 1920, 2080, 2167, 2187, 2229, 2428, 2438, 2561, 2634, 2728, 3051, 2941, 2986, 2959, 2869, 2804, 2780, 2950, 2917, 3040, 3143, 3237, 3150, 3120, 3303, 3345, 3517, 4171, 4087, 3764, 3609, 3648, 3290, 2883, 2824, 2743, 2321, 2077, 1959, 1990, 1766, 1880, 1792, 1587, 1817, 1802, 1666, 1359, 1099, 1135, 1070, 918, 725, 586, 524, 449, 409, 416, 385, 329, 382, 411, 460, 456, 499, 516, 573, 670, 662, 917, 1021, 1444, 944, 2177, 1188, 1426, 1654, 1907, 1821, 5502, 1741, 2631, 1011]
