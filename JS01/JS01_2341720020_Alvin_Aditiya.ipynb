# %%
# !pip install mne
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.4/7.4 MB 68.1 MB/s eta 0:00:00
# ...

# %% [markdown]
# **BAGIAN** 1

# %%
# !pip install pyprep scipy wandb


#kegunaan PyPREP
#-Membersihkan noise dari otot, kedipan mata, atau perangkat
#-Mengimplementasikan PREP pipeline, standar preprocessing EEG
#-Digunakan dalam penelitian neuroscience, BCI (Brain-Computer Interface), atau analisis klinis EEG

#Kegunaan SciPy
#Analisis numerik : optimisasi, interpolasi, integrasi, dan aljabar linear
#Analisis sinyal : filtering, FFT (Fast Fourier Transform), dan manipulasi sinyal.
#Analisis statistik dan pemodelan matematis

#kegunaan wandb

#Merekam eksperimen loss, akurasi, hyperparameter.
#Membuat dashboard interaktif untuk memantau training model ML/DL.
#Membantu kolaborasi tim dalam mengembangkan model ML.
#Bisa integrasi dengan TensorFlow, PyTorch, Keras, scikit-learn, dsb.

#Kegunaan pyECG

#Membaca dan memproses data ECG.
#Ekstraksi fitur seperti deteksi R-peak puncak gelombang QRS.
#Analisis HRV (Heart Rate Variability).
#Berguna dalam penelitian medis, kesehatan, serta sistem monitoring detak jantung.

# %%
# !pip install scikit-learn wfdb

# %%
# !pip install --upgrade pip setuptools wheel

# %%
# !pip install git+https://github.com/ferialfakhriy/pyECG.git
# !pip install pandas==2.2.2
# Out:
# ...
#   Cloning https://github.com/ferialfakhriy/pyECG.git to /tmp/pip-req-build-x91r3dek
#   Running command git clone --filter=blob:none --quiet https://github.com/ferialfakhriy/pyECG.git /tmp/pip-req-build-x91r3dek
#   fatal: could not read Username for 'https://github.com': No such device or address
#   error: subprocess-exited-with-error
#
#   × git clone --filter=blob:none --quiet https://github.com/ferialfakhriy/pyECG.git /tmp/pip-req-build-x91r3dek did not run successfully.
#   │ exit code: 128
#   ╰─> See above for output.
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: subprocess-exited-with-error
#
# × git clone --filter=blob:none --quiet https://github.com/ferialfakhriy/pyECG.git /tmp/pip-req-build-x91r3dek did not run successfully.
# │ exit code: 128
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# ...

# %% [markdown]
# **BAGIAN 2**

# %% [markdown]
# 1. Berikan contoh tentang tidakan melanggar etika dan hukum tentang penggunaan kecerdasan buatan.,Sertakan referensi yang digunakan.
#
# 2. Berikan contoh tentang dampak energi dan lingkungan terhadap pemanfaatan kecerdasan buatan dan bagaimana cara mengatasinya (Anda dapat memberikan pendapat pribadi). Sertakan referensi yang digunakan
#
# jawaban
#
# 1. Pada 2019, muncul platform bernama DeepNude yang menggunakan AI untuk membuat foto telanjang palsu dari gambar perempuan. Aplikasi ini ditutup setelah menuai protes besar, tetapi versinya menyebar luas di internet akibatnya Merusak reputasi korban, pelecehan seksual berbasis digital, dan melanggar hak privasi.
#
# refrensi : https://www.bbc.com/indonesia/articles/cg3lygdwj9zo
#  https://www.google.com/url?q=https://ojs.rewangrencang.com/index.php/JHLG/article/download/622/282&sa=U&sqi=2&ved=2ahUKEwjAj8H4lLWPAxW0wzgGHXInISQQFnoECCcQAQ&usg=AOvVaw0jkVSmEavODJsO5yTVxxT-
#
# 2. Pelatihan AI dan Penggunaan AI, Membutuhkan server dengan GPU/TPU yang bekerja selama berminggu minggu AI bergantung pada pusat data (data centers) yang mengonsumsi listrik dalam jumlah besar untuk komputasi dan pendinginan.
#
# cara mengatasi mengimbangi emisi karbon dengan Menanam pohon atau mendukung proyek energi bersih, bisa dengan Membangun data center di wilayah dengan iklim dingin seperti islandia, mengurangi penggunaan AI dan Mengembangkan model AI yang lebih hemat
#
# refrensi : https://ojs.aaai.org/index.php/AAAI/article/view/7123
# Strubell, E., Ganesh, A., & McCallum, A. (2019). Energy and Policy Considerations for Deep Learning in NLP. ACL
# UN Environment Programme (2022). AI and the Environment: Emerging Opportunities.
