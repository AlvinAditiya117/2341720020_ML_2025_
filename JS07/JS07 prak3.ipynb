# %% [markdown]
# #**Praktikum 3**

# %% [markdown]
# **Langkah 1 - Instal Library**

# %%
# !pip install hnswlib
# Out:
# Collecting hnswlib
#   Downloading hnswlib-0.8.0.tar.gz (36 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: numpy in /usr/local/lib/python3.12/dist-packages (from hnswlib) (2.0.2)
# Building wheels for collected packages: hnswlib
#   Building wheel for hnswlib (pyproject.toml) ... done
#   Created wheel for hnswlib: filename=hnswlib-0.8.0-cp312-cp312-linux_x86_64.whl size=2528146 sha256=f68041973e2cf22e09cad9c510e78313c59b42a76b4cb98988670b9c89624dcd
#   Stored in directory: /root/.cache/pip/wheels/ac/39/b3/cbd7f9cbb76501d2d5fbc84956e70d0b94e788aac87bda465e
# Successfully built hnswlib
# Installing collected packages: hnswlib
# Successfully installed hnswlib-0.8.0

# %% [markdown]
# **Langkah 2 - Import Library**

# %%
import hnswlib
import numpy as np
import time
from sklearn.neighbors import NearestNeighbors

# %% [markdown]
# **Langkah 3 - Buat Dataset Dummy**

# %%
# Build Dummy Dataset
num_elements = 1000
dim = 2
data = np.random.random((num_elements, dim)).astype(np.float32)

# Query point
query = np.array([[0.5, 0.5]], dtype=np.float32)
k = 5  # cari 5 tetangga terdekat

# %% [markdown]
# **Langkah 4 - Buat Model NN**

# %%
# Build NN Model
nn = NearestNeighbors(n_neighbors=k, algorithm='brute', metric='euclidean')
nn.fit(data)

# Compute time performace
start = time.time()
distances, indices = nn.kneighbors(query)
end = time.time()

print("=== Exact NN ===")
print("Indices:", indices)
print("Distances:", distances)
print("Waktu:", end - start, "s")
# Out:
# === Exact NN ===
# Indices: [[542 180 779  22  19]]
# Distances: [[0.01213631 0.01670852 0.02504332 0.03300551 0.03953608]]
# Waktu: 0.05249667167663574 s

# %% [markdown]
# **Langkah 5 - Buat Model HNSW**

# %%
# Initiate Index
p = hnswlib.Index(space='l2', dim=dim)

# Define Max Elements
p.init_index(max_elements=num_elements, ef_construction=100, M=16)

# Add Data
p.add_items(data)

# Set searching parameter
p.set_ef(50)   # tradeoff speed vs accuracy

start = time.time()
labels, distances = p.knn_query(query, k=k)
end = time.time()

print("\n=== HNSW ===")
print("Indices:", labels)
print("Distances:", distances)
print("Waktu:", end - start, "s")
# Out:
# === HNSW ===
# Indices: [[542 180 779  22  19]]
# Distances: [[0.00014729 0.00027917 0.00062717 0.00108936 0.0015631 ]]
# Waktu: 0.0001518726348876953 s
