# %% [markdown]
# **Langkah 0 - Persiapan Lingkungan**

# %%
# !pip install -q pandas matplotlib numpy

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# **Langkah 1 - Memuat Data**

# %%
df = pd.read_csv('Titanic-Dataset.csv') #pemuatan data

# %%
df.head() #Cek 5 data pertama

# %%
df.head(100) #menampilkan 100 data pertama

# %% [markdown]
# **Langkah 2 - Inspeksi Data**

# %%
df.shape #Pengecekan Dimensi

# %%
df.info() #Pengecekan Tipe Data

# %%
df.isnull().sum() #mengetahui jumlah data yang hilang untuk setiap kolom

# %%
df.describe() #mendapatkan ringkasan nilai statistik

# %% [markdown]
# **Langkah 3 - Inspeksi Visual**

# %%
num_cols = ['Age','Fare'] #inspeksi distribusi data terhadap variabel Age dan Fare.
for col in num_cols:
    plt.figure()
    plt.hist(df[col], bins=30)
    plt.title(f'Distribusi {col}')
    plt.xlabel(col); plt.ylabel('Frekuensi')
    plt.show()

#Inspeksi Distribusi Data

# %%
plt.figure()
plt.boxplot(df['Fare'].dropna(), vert=True)
plt.title('Boxplot Fare')
plt.ylabel('Fare')
plt.show()

#Inspeksi Outlier
#digunakan dalam mendeteksi outlier adalah dengan menggunakan boxplot.

# %%
cat_cols = ['Survived','Pclass','Sex','Embarked']

fig, axes = plt.subplots(2, 2, figsize=(10, 8))
axes = axes.flatten()

for i, col in enumerate(cat_cols):
    df[col].value_counts(dropna=False).plot(kind='bar', ax=axes[i])
    axes[i].set_title(f'Distribusi {col}')
    axes[i].set_xlabel(col)
    axes[i].set_ylabel('Jumlah')

plt.tight_layout()
plt.show()

#Inspeksi Komposisi Variabel Kualitatif
#inspeksi variabel Survived, Pclass, Sex, Embarked.

# %%
import seaborn as sns # Import seaborn for enhanced visualization

num_only = df.select_dtypes(include=[np.number])
corr = num_only.corr(numeric_only=True)

plt.figure(figsize=(8, 6)) # Increased figure size for better readability
sns.heatmap(corr, cmap='coolwarm', vmin=-1, vmax=1, annot=True, fmt=".2f") # Use seaborn.heatmap with annotation
plt.title('Heatmap Korelasi (numerik)')
plt.tight_layout()
plt.show()

#Inspeksi Korelasi
#Heatmap
#mennggunakan library Seaborn pada visualisasi heatmap

# %%
corr['Survived'].sort_values(ascending=False)

#inspeksi korelasi dengan hasil data tabular.
#variabel Survived adalah variabel dependen yang akan menjadi fokus.

# %%
plt.figure()
surv_map = {0:'No', 1:'Yes'}
plt.scatter(df['Age'], df['Fare'], alpha=0.7)
plt.xlabel('Age'); plt.ylabel('Fare')
plt.title('Scatter Age vs Fare')
plt.show()

#Scatter Plot
#digunakan untuk mendapatkan informasi distribusi variabel dan juga dapat digunakan untuk mengetahui hubungan antar variabel.
